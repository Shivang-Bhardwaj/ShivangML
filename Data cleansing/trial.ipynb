# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv(r"E:\ML\Useful data\Bengaluru_House_Data.csv")
df.tail(8)
# Out:
#                   area_type   availability               location size  \
# 13312  Super built-up  Area  Ready To Move              Bellandur    2
# 13313  Super built-up  Area  Ready To Move            Uttarahalli    3
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout    3
# 13315        Built-up  Area  Ready To Move             Whitefield    5
# 13316  Super built-up  Area  Ready To Move          Richards Town    4
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar    2
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar    4
# 13319  Super built-up  Area  Ready To Move           Doddathoguru    1
#
#       total_sqft  bath  balcony  price
# 13312       1262   2.0      2.0   47.0
# 13313       1345   2.0      1.0   57.0
# 13314       1715   3.0      3.0  112.0
# 13315       3453   4.0      0.0  231.0
# 13316       3600   5.0      NaN  400.0
# 13317       1141   2.0      1.0   60.0
# 13318       4689   4.0      1.0  488.0
# ...
