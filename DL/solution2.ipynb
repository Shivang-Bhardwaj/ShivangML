# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# d:\Users\DELL PC\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
import tensorflow as tf

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
# using relu


model = keras.Sequential(
    [
        keras.Input(shape=input_shape),

        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Flatten(),
        layers.Dropout(0.25),

        layers.Dense(64, activation = 'relu'),
        layers.Dropout(0.25),
        
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 1600)              0
#
#  dropout_3 (Dropout)         (None, 1600)              0
#
#  dense_4 (Dense)             (None, 64)                102464
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# ...
# Total params: 121,930
# Trainable params: 121,930
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 45s 100ms/step - loss: 0.6830 - accuracy: 0.7514 - val_loss: 0.4190 - val_accuracy: 0.8437
# Epoch 2/15
# 422/422 [==============================] - 47s 112ms/step - loss: 0.4388 - accuracy: 0.8431 - val_loss: 0.3611 - val_accuracy: 0.8680
# Epoch 3/15
# 422/422 [==============================] - 48s 113ms/step - loss: 0.3842 - accuracy: 0.8623 - val_loss: 0.3254 - val_accuracy: 0.8782
# Epoch 4/15
# 422/422 [==============================] - 46s 110ms/step - loss: 0.3529 - accuracy: 0.8705 - val_loss: 0.3016 - val_accuracy: 0.8903
# Epoch 5/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.3273 - accuracy: 0.8802 - val_loss: 0.2847 - val_accuracy: 0.8925
# Epoch 6/15
# 422/422 [==============================] - 37s 88ms/step - loss: 0.3145 - accuracy: 0.8841 - val_loss: 0.2788 - val_accuracy: 0.8980
# Epoch 7/15
# ...

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.25023582577705383
# Test accuracy: 0.9110999703407288

# %%
# using atan


model = keras.Sequential(
        [
        keras.Input(shape=input_shape),

        layers.Conv2D(32, kernel_size=(3, 3), ),
        layers.Lambda( lambda x : tf.math.atan(x)  ),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Conv2D(64, kernel_size=(3, 3) ),
        layers.Lambda( lambda x : tf.math.atan(x)  ),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Flatten(),
        layers.Dropout(0.25),

        layers.Dense(64 ),
        layers.Lambda( lambda x : tf.math.atan(x)  ),
        layers.Dropout(0.25),
        
        layers.Dense(num_classes, activation="softmax"),
    ]
)
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Epoch 1/15
# 422/422 [==============================] - 56s 129ms/step - loss: 0.5962 - accuracy: 0.7857 - val_loss: 0.4008 - val_accuracy: 0.8547
# Epoch 2/15
# 422/422 [==============================] - 57s 134ms/step - loss: 0.4120 - accuracy: 0.8535 - val_loss: 0.3577 - val_accuracy: 0.8690
# Epoch 3/15
# 422/422 [==============================] - 64s 152ms/step - loss: 0.3726 - accuracy: 0.8670 - val_loss: 0.3261 - val_accuracy: 0.8797
# Epoch 4/15
# 422/422 [==============================] - 63s 150ms/step - loss: 0.3432 - accuracy: 0.8782 - val_loss: 0.3137 - val_accuracy: 0.8880
# Epoch 5/15
# 422/422 [==============================] - 63s 150ms/step - loss: 0.3273 - accuracy: 0.8820 - val_loss: 0.2975 - val_accuracy: 0.8908
# Epoch 6/15
# 422/422 [==============================] - 63s 148ms/step - loss: 0.3112 - accuracy: 0.8863 - val_loss: 0.2944 - val_accuracy: 0.8898
# Epoch 7/15
# ...

# %%
# x.atan(x)


model = keras.Sequential(
        [
        keras.Input(shape=input_shape),

        layers.Conv2D(32, kernel_size=(3, 3), ),
        layers.Lambda( lambda x : x*tf.math.atan(x)  ),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Conv2D(64, kernel_size=(3, 3) ),
        layers.Lambda( lambda x : x*tf.math.atan(x)  ),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Flatten(),
        layers.Dropout(0.25),

        layers.Dense(64 ),
        layers.Lambda( lambda x : x*tf.math.atan(x)  ),
        layers.Dropout(0.25),
        
        layers.Dense(num_classes, activation="softmax"),
    ]
)
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Epoch 1/15
# 422/422 [==============================] - 56s 130ms/step - loss: 0.8832 - accuracy: 0.6963 - val_loss: 0.4914 - val_accuracy: 0.8205
# Epoch 2/15
# 422/422 [==============================] - 54s 129ms/step - loss: 0.5305 - accuracy: 0.8094 - val_loss: 0.4459 - val_accuracy: 0.8400
# Epoch 3/15
# 422/422 [==============================] - 60s 142ms/step - loss: 0.4541 - accuracy: 0.8362 - val_loss: 0.3732 - val_accuracy: 0.8650
# Epoch 4/15
# 422/422 [==============================] - 66s 157ms/step - loss: 0.4099 - accuracy: 0.8507 - val_loss: 0.3421 - val_accuracy: 0.8775
# Epoch 5/15
# 422/422 [==============================] - 57s 135ms/step - loss: 0.3834 - accuracy: 0.8620 - val_loss: 0.3283 - val_accuracy: 0.8827
# Epoch 6/15
# 422/422 [==============================] - 57s 136ms/step - loss: 0.3622 - accuracy: 0.8681 - val_loss: 0.3078 - val_accuracy: 0.8893
# Epoch 7/15
# ...

# %%
# custom  made 1


model = keras.Sequential(
        [
        keras.Input(shape=input_shape),

        layers.Conv2D(32, kernel_size=(3, 3), ),
        layers.Lambda( lambda x : tf.where(x>0.0, x*tf.math.atan(x), 0.01*x)  ),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Conv2D(64, kernel_size=(3, 3) ),
        layers.Lambda( lambda x : tf.where(x>0.0, x*tf.math.atan(x), 0.01*x)  ),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Flatten(),
        layers.Dropout(0.25),

        layers.Dense(64 ),
        layers.Lambda( lambda x : tf.where(x>0.0, x*tf.math.atan(x), 0.01*x)  ),
        layers.Dropout(0.25),
        
        layers.Dense(num_classes, activation="softmax"),
    ]
)
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Epoch 1/15
# 422/422 [==============================] - 80s 186ms/step - loss: 0.8606 - accuracy: 0.6975 - val_loss: 0.4506 - val_accuracy: 0.8367
# Epoch 2/15
# 422/422 [==============================] - 68s 161ms/step - loss: 0.4801 - accuracy: 0.8275 - val_loss: 0.3906 - val_accuracy: 0.8500
# Epoch 3/15
# 422/422 [==============================] - 74s 174ms/step - loss: 0.4235 - accuracy: 0.8456 - val_loss: 0.3603 - val_accuracy: 0.8650
# Epoch 4/15
# 422/422 [==============================] - 68s 161ms/step - loss: 0.3883 - accuracy: 0.8587 - val_loss: 0.3315 - val_accuracy: 0.8783
# Epoch 5/15
# 422/422 [==============================] - 71s 169ms/step - loss: 0.3630 - accuracy: 0.8659 - val_loss: 0.3137 - val_accuracy: 0.8817
# Epoch 6/15
# 422/422 [==============================] - 82s 195ms/step - loss: 0.3420 - accuracy: 0.8738 - val_loss: 0.3042 - val_accuracy: 0.8865
# Epoch 7/15
# ...

# %%
# custom  made 2


model = keras.Sequential(
        [
        keras.Input(shape=input_shape),

        layers.Conv2D(32, kernel_size=(3, 3), ),
        layers.Lambda( lambda x : tf.where(x>0.0, x*tf.math.atan(x), tf.math.exp(x)-1)  ),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Conv2D(64, kernel_size=(3, 3) ),
        layers.Lambda( lambda x : tf.where(x>0.0, x*tf.math.atan(x), tf.math.exp(x)-1)  ),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Flatten(),
        layers.Dropout(0.25),

        layers.Dense(64 ),
        layers.Lambda( lambda x : tf.where(x>0.0, x*tf.math.atan(x), tf.math.exp(x)-1)  ),
        layers.Dropout(0.25),
        
        layers.Dense(num_classes, activation="softmax"),
    ]
)
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Epoch 1/15
# 422/422 [==============================] - 85s 196ms/step - loss: 0.6978 - accuracy: 0.7442 - val_loss: 0.4448 - val_accuracy: 0.8333
# Epoch 2/15
# 422/422 [==============================] - 90s 213ms/step - loss: 0.4657 - accuracy: 0.8311 - val_loss: 0.3818 - val_accuracy: 0.8587
# Epoch 3/15
# 422/422 [==============================] - 91s 216ms/step - loss: 0.4134 - accuracy: 0.8496 - val_loss: 0.3596 - val_accuracy: 0.8692
# Epoch 4/15
# 422/422 [==============================] - 111s 264ms/step - loss: 0.3786 - accuracy: 0.8626 - val_loss: 0.3308 - val_accuracy: 0.8752
# Epoch 5/15
# 422/422 [==============================] - 110s 261ms/step - loss: 0.3585 - accuracy: 0.8677 - val_loss: 0.3173 - val_accuracy: 0.8837
# Epoch 6/15
# 422/422 [==============================] - 97s 230ms/step - loss: 0.3393 - accuracy: 0.8751 - val_loss: 0.3090 - val_accuracy: 0.8835
# Epoch 7/15
# ...

# %%
# custom  made 3


model = keras.Sequential(
        [
        keras.Input(shape=input_shape),

        layers.Conv2D(32, kernel_size=(3, 3), ),
        layers.Lambda( lambda x : tf.where(x>0.0, x*tf.math.atan(x), .5*(tf.math.exp(x)-1))  ),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Conv2D(64, kernel_size=(3, 3) ),
        layers.Lambda( lambda x : tf.where(x>0.0, x*tf.math.atan(x), .5*tf.math.exp(x)-1)  ),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Flatten(),
        layers.Dropout(0.25),

        layers.Dense(64 ),
        layers.Lambda( lambda x : tf.where(x>0.0, x*tf.math.atan(x), .5*tf.math.exp(x)-1)  ),
        layers.Dropout(0.25),
        
        layers.Dense(num_classes, activation="softmax"),
    ]
)
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Epoch 1/15
# 422/422 [==============================] - 86s 199ms/step - loss: 0.6607 - accuracy: 0.7541 - val_loss: 0.4365 - val_accuracy: 0.8357
# Epoch 2/15
# 422/422 [==============================] - 84s 198ms/step - loss: 0.4666 - accuracy: 0.8276 - val_loss: 0.3885 - val_accuracy: 0.8548
# Epoch 3/15
# 422/422 [==============================] - 85s 201ms/step - loss: 0.4203 - accuracy: 0.8470 - val_loss: 0.3687 - val_accuracy: 0.8675
# Epoch 4/15
# 422/422 [==============================] - 82s 194ms/step - loss: 0.3891 - accuracy: 0.8572 - val_loss: 0.3604 - val_accuracy: 0.8673
# Epoch 5/15
# 422/422 [==============================] - 87s 205ms/step - loss: 0.3664 - accuracy: 0.8660 - val_loss: 0.3266 - val_accuracy: 0.8745
# Epoch 6/15
# 422/422 [==============================] - 88s 209ms/step - loss: 0.3516 - accuracy: 0.8694 - val_loss: 0.3132 - val_accuracy: 0.8825
# Epoch 7/15
# ...
