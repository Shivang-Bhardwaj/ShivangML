# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
def identity_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def convolutional_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Processing Residue with conv(1,1)
    x_skip = tf.keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def ResNet34(shape = (224, 224, 3), classes = 10):
    # Step 1 (Setup Input Layer)
    x_input = tf.keras.layers.Input(shape)
    x = tf.keras.layers.ZeroPadding2D((3, 3))(x_input)
    # Step 2 (Initial Conv layer along with maxPool)
    x = tf.keras.layers.Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    # Define size of sub-blocks and initial filter size
    block_layers = [3, 4, 6, 3]
    filter_size = 64
    # Step 3 Add the Resnet Blocks
    for i in range(4):
        if i == 0:
            # For sub-block 1 Residual/Convolutional block not needed
            for j in range(block_layers[i]):
                x = identity_block(x, filter_size)
        else:
            # One Residual/Convolutional Block followed by Identity blocks
            # The filter size will go on increasing by a factor of 2
            filter_size = filter_size*2
            x = convolutional_block(x, filter_size)
            for j in range(block_layers[i] - 1):
                x = identity_block(x, filter_size)
    # Step 4 End Dense Network
    x = tf.keras.layers.AveragePooling2D((2,2), padding = 'same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation = 'relu')(x)
    x = tf.keras.layers.Dense(classes, activation = 'softmax')(x)
    model = tf.keras.models.Model(inputs = x_input, outputs = x, name = "ResNet34")
    return model

# %%
model = ResNet34()

# %%
model.summary()
# Out:
# Model: "ResNet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_1 (ZeroPadding2  (None, 230, 230, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv2d_36 (Conv2D)             (None, 115, 115, 64  9472        ['zero_padding2d_1[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 115, 115, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_33 (Activation)     (None, 115, 115, 64  0           ['batch_normalization_33[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 58, 58, 64)  0           ['activation_33[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 58, 58, 64)   36928       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 58, 58, 64)  256         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 58, 58, 64)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 58, 58, 64)   36928       ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 58, 58, 64)  256         ['conv2d_38[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 58, 58, 64)   0           ['batch_normalization_35[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  activation_35 (Activation)     (None, 58, 58, 64)   0           ['add_16[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 58, 58, 64)   36928       ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 58, 58, 64)  256         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 58, 58, 64)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 58, 58, 64)   36928       ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 58, 58, 64)  256         ['conv2d_40[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 58, 58, 64)   0           ['batch_normalization_37[0][0]',
#                                                                   'activation_35[0][0]']
#
#  activation_37 (Activation)     (None, 58, 58, 64)   0           ['add_17[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 58, 58, 64)   36928       ['activation_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 58, 58, 64)  256         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 58, 58, 64)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 58, 58, 64)   36928       ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 58, 58, 64)  256         ['conv2d_42[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 58, 58, 64)   0           ['batch_normalization_39[0][0]',
#                                                                   'activation_37[0][0]']
#
#  activation_39 (Activation)     (None, 58, 58, 64)   0           ['add_18[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 29, 29, 128)  73856       ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 29, 29, 128)  512        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 29, 29, 128)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 29, 29, 128)  147584      ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 29, 29, 128)  512        ['conv2d_44[0][0]']
#  ormalization)
#
#  conv2d_45 (Conv2D)             (None, 29, 29, 128)  8320        ['activation_39[0][0]']
#
#  add_19 (Add)                   (None, 29, 29, 128)  0           ['batch_normalization_41[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  activation_41 (Activation)     (None, 29, 29, 128)  0           ['add_19[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 29, 29, 128)  147584      ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 29, 29, 128)  512        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 29, 29, 128)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 29, 29, 128)  147584      ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 29, 29, 128)  512        ['conv2d_47[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 29, 29, 128)  0           ['batch_normalization_43[0][0]',
#                                                                   'activation_41[0][0]']
#
#  activation_43 (Activation)     (None, 29, 29, 128)  0           ['add_20[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 29, 29, 128)  147584      ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 29, 29, 128)  512        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 29, 29, 128)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 29, 29, 128)  147584      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 29, 29, 128)  512        ['conv2d_49[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 29, 29, 128)  0           ['batch_normalization_45[0][0]',
#                                                                   'activation_43[0][0]']
#
#  activation_45 (Activation)     (None, 29, 29, 128)  0           ['add_21[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 29, 29, 128)  147584      ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 29, 29, 128)  512        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 29, 29, 128)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 29, 29, 128)  147584      ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 29, 29, 128)  512        ['conv2d_51[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 29, 29, 128)  0           ['batch_normalization_47[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_47 (Activation)     (None, 29, 29, 128)  0           ['add_22[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 15, 15, 256)  295168      ['activation_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 15, 15, 256)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_53[0][0]']
#  ormalization)
#
#  conv2d_54 (Conv2D)             (None, 15, 15, 256)  33024       ['activation_47[0][0]']
#
#  add_23 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_49[0][0]',
#                                                                   'conv2d_54[0][0]']
#
#  activation_49 (Activation)     (None, 15, 15, 256)  0           ['add_23[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 15, 15, 256)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_56[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_51[0][0]',
#                                                                   'activation_49[0][0]']
#
#  activation_51 (Activation)     (None, 15, 15, 256)  0           ['add_24[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 15, 15, 256)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_58[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_53[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_53 (Activation)     (None, 15, 15, 256)  0           ['add_25[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 15, 15, 256)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_60[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_55[0][0]',
#                                                                   'activation_53[0][0]']
#
#  activation_55 (Activation)     (None, 15, 15, 256)  0           ['add_26[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 15, 15, 256)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_62[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_57[0][0]',
#                                                                   'activation_55[0][0]']
#
#  activation_57 (Activation)     (None, 15, 15, 256)  0           ['add_27[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 15, 15, 256)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 15, 15, 256)  590080      ['activation_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_64[0][0]']
#  ormalization)
#
#  add_28 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_59[0][0]',
#                                                                   'activation_57[0][0]']
#
#  activation_59 (Activation)     (None, 15, 15, 256)  0           ['add_28[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 8, 8, 512)    1180160     ['activation_59[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_60[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 8, 8, 512)    2359808     ['activation_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_66[0][0]']
#  ormalization)
#
#  conv2d_67 (Conv2D)             (None, 8, 8, 512)    131584      ['activation_59[0][0]']
#
#  add_29 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_61[0][0]',
#                                                                   'conv2d_67[0][0]']
#
#  activation_61 (Activation)     (None, 8, 8, 512)    0           ['add_29[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 8, 8, 512)    2359808     ['activation_61[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_62[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 8, 8, 512)    2359808     ['activation_62[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_69[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_63[0][0]',
#                                                                   'activation_61[0][0]']
#
#  activation_63 (Activation)     (None, 8, 8, 512)    0           ['add_30[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 8, 8, 512)    2359808     ['activation_63[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_64[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 8, 8, 512)    2359808     ['activation_64[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_71[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_65[0][0]',
#                                                                   'activation_63[0][0]']
#
#  activation_65 (Activation)     (None, 8, 8, 512)    0           ['add_31[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 4, 4, 512)   0           ['activation_65[0][0]']
#  oling2D)
#
#  flatten_1 (Flatten)            (None, 8192)         0           ['average_pooling2d_1[0][0]']
#
#  dense_2 (Dense)                (None, 512)          4194816     ['flatten_1[0][0]']
#
#  dense_3 (Dense)                (None, 10)           5130        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 25,506,570
# Trainable params: 25,491,338
# Non-trainable params: 15,232
# __________________________________________________________________________________________________
